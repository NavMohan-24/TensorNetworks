# %% [markdown]
# ## T02.2 Implementation of updateLeft
#
#  Author: Changkai Zhang <https://chx-zh.cc> \
#  Email: changkai.zhang@physik.lmu.de
#
#  In this tutorial, we will implement another function used frequently during
#  this course, called "updateLeft". Consider the following tensors $C$, $A$, $B$
#  and $X$:
#
#   <div>
#  <img src="attachment:T02.2.1.png" style="width:400px;"/>
#  </div>
#
#  The bond dimensions $D$, $d$ and $w$ are indicated next to the legs, the leg
#  numbering at the tip of the legs. Consider the case where $D \gg d \simeq w$.
#  We want to contract the tensors in the following way:

# %% [markdown]
# <div>
#  <img src="attachment:T02.2.2.png" style="width:170px;"/>
#  </div>

# %% [markdown]
# Here, we have again indicated the leg ordering of the final object at the
#  tip of the legs. Note that we consider the conjugate of $B$, which means its
#  leg directions have been flipped.

# %% [markdown]
# ### Exercise (a): Contraction pattern
#
#  [i] Figure out the optimal contraction pattern in case $D \gg d \simeq w$.
#  Write down the tensor network diagrams of the optimal pattern step by step and
#  indicate both the computational cost and the leg orderings. What is the leading
#  order, i.e. the most expensive step?

# %% [markdown]
# ### Exercise (b): implementation of updateLeft
#
# (i) Create a function called "updateLeft" in the Tensor folder. It should
#  have the following input and output:
#
#  Input: $C$, rank of $C$, $B$ (assume rank 3), $X$, rank of $X$, $A$ (assume
#  rank 3)
#
#  Output: $C_{\mathrm{new}}$, which is the result of the contraction
#
#  [ii] Write down some pseudocode explaining the steps taken in your function.
#  Remember the correct leg ordering!
#
#  (iii) To test your funtion, create a script which randomly initializes $C$,
#  $A$, $B$ and $X$. Choose $d=4$, $w=6$ and $D\geq 100$. Measure the CPU time
#  for the contraction as a function of $D$. Can you confirm the scaling you found
#  in (a)?
